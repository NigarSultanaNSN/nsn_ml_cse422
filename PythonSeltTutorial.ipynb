# %%
print('Hello world')
# Out:
# Hello world

# %%
n= int(input('Enter a number'))
if n>2:
  print('number is greater than two')
else: 
  print('number is not greater than two')
# Out:
# Enter a number1
# number is not greater than two

# %%
a= int(input('Enter first number:  '))
b= int(input('Enter the second number:  '))
if a==b:
  print('Both are equal')
elif a>b:
  print('first number is greater than second number.')
else: 
  print('second number is greater than first number.')
# Out:
# Enter first number:  7
# Enter the second number:  9
# second number is greater than first number.

# %%
i=2
while i<11:
 print('Ohhoh! ')
 i += 1
# Out:
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!

# %%
i=2
while i<11:
 print('Ohhoh! ')
 if i==8:
   break
 i += 1
# Out:
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!
# Ohhoh!

# %%
for p in range(3, 30, 5):
  print('here is my') 
  print(p)
if p == 29:
  print('Ahhah!')
else:
  print('No way!')
# Out:
# here is my
# 3
# here is my
# 8
# here is my
# 13
# here is my
# 18
# here is my
# 23
# here is my
# 28
# No way!

# %%
def my_func(Birth_year):
  return 2021-Birth_year


my_func(1998)
my_func(1997)
# Out:
# 24

# %%
name= 'DemonChan'
l= len(name)
print(name[4])
print(l)
for k in range(0,9):
 print(name[k])
# Out:
# n
# 9
# D
# e
# m
# o
# n
# C
# h
# a
# n

# %%
C1= 'Black'
C2= 'Red'
C3= 'Purple'
C4= 'Blue'
N=[C1, C2, C3, C4]
print(N)
N.append('Comics')
print(len(N))
print(N)
N.sort()
print(N)
N.pop(2)
print(N)
# Out:
# ['Black', 'Red', 'Purple', 'Blue']
# 5
# ['Black', 'Red', 'Purple', 'Blue', 'Comics']
# ['Black', 'Blue', 'Comics', 'Purple', 'Red']
# ['Black', 'Blue', 'Purple', 'Red']

# %%
def gen_alg(population, fitness):
 nmax= 1000000
 n= nmax
 goal_fit= compute_goal_fit(len(random.choice(population)))
 print("\ngoal fit for current population", goal_fit)
 print("\nproblem dimension: ", len(random.choice(population)), "x", len(random.choice(population)))
 print("population size: ", len(population))
 print("max generations: ", n)
 print("\nrunning...")
 while n>0:
     new_population= [ ]
     for i in range(len(population)):
          x= random_selection(population, fitness_fn, goal_fit)
          child= reproduce(x)
          if random.uniform(0, 1)< 1.0:
             child= mutation(child)
          if fitness(child, goal_fit) == goal_fit:
             print("...done. \n")
             print("result ", child, " found in ", max - n, " generations. \n")
             return child
          new_population.append(child)
     
     population= new_population
     n-= 1
 print("\nno solution found in ", nmax, "generations, try again.\n")
 return None
