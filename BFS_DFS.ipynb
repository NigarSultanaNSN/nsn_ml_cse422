# %%
#Queue
from queue import Queue
myQueue = Queue(maxsize= 5)
myQueue.put("A")                  #put >> push or enqueue
myQueue.get()
# Out:
# 'A'

# %%
#Stack
from queue import LifoQueue
myStack = LifoQueue(maxsize= 5)
myStack.put("K")
myStack.get()
# Out:
# 'K'

# %%
#BFS
from queue import Queue
bfs_Queue= Queue()
visited_list= {}
bfs_traversal_output= []

# %%
bfs_Queue.put(graph[0])
while not bfs_Queue.empty():
  for n in graph:
    if (graph[n] == goal_node):
      break
    elif (graph[n] != goal_node):
      bfs_Queue.get()
      visited_list[n]= graph[n]
      bfs_Queue.put(graph[n+1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0ade7fdd3edb> in <module>()
# ----> 1 bfs_Queue.put(graph[0])
#       2 while not bfs_Queue.empty():
#       3   for n in graph:
#       4     if (graph[n] == goal_node):
#       5       break
#
# NameError: name 'graph' is not defined
